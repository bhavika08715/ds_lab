# %%
import seaborn as sns
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data,color='aquamarine')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=sns.load_dataset("tips")
sns.countplot(x='sex',data=df,palette='Set1')
plt.show()
# Out:
# /tmp/ipykernel_979/3382604306.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=df,palette='Set1')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("Iris.csv")
sns.countplot(x="Species",data=df,color='aquamarine')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("Iris.csv")
sns.lineplot(x="SepalLengthCm",y="SepalWidthCm",data=data,color='aquamarine')
sns.set_style("darkgrid")
plt.show()

# %%
import seaborn
import matplotlib.pyplot as plt
data=seaborn.load_dataset('tips')
seaborn.pairplot(data,hue='day')
plt.show()

# %%
import seaborn
import matplotlib.pyplot as plt
data=seaborn.load_dataset('tips')
seaborn.pairplot(data,hue='sex')
plt.show()

# %%
import seaborn
import matplotlib.pyplot as plt
data=seaborn.load_dataset('tips')
c_p={'Male':'aquamarine','Female':'aqua'}
seaborn.pairplot(data,hue='sex',palette=c_p)
plt.show()

# %%
import seaborn
import matplotlib.pyplot as plt
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x=x,y=y)
plt.show()

# %%
import seaborn
import matplotlib.pyplot as plt
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x=x,y=y,fill=True)
plt.show()

# %%
import seaborn as sns
sns.set_style("whitegrid")
sns.displot(data['total_bill'],kde = False,color='aquamarine',bins=20)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = np.random.randint(1, 100,(10, 10))
sns.heatmap(data,vmin =30,vmax=70)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = np.random.randint(1, 100,(10, 10))
sns.heatmap(data,cmap='tab20')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = np.random.randint(1, 100,(10, 10))
sns.heatmap(data,cmap='coolwarm',center=50)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv("Iris.csv")
data = data.select_dtypes(include='number')
sns.heatmap(data)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
iris = pd.read_csv("Iris.csv")
print(iris.head())
sns.heatmap(iris.corr(numeric_only=True),annot=True, cmap="coolwarm")
plt.title("Iris Dataset Correlation Heatmap")
plt.show()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import matplotlib.pyplot as plt
data = [0, 5, 10, 15, 20, 25, 30]
plt.hist(data,bins=5,color='aquamarine',edgecolor='black')
plt.hist("Histogram Example")
plt.xlabel("Value Range")
plt.ylabel("Frequency")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
iris = pd.read_csv("Iris.csv")
plt.hist(iris["SepalLengthCm"], bins=5, color='aquamarine', edgecolor='black')
plt.title("Histogram of Sepal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("Iris.csv")
sns.violinplot(x='Species',y='PetalLengthCm',data=df, color='aquamarine')
plt.title("Violin Plot")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
group1 = [12, 15, 20, 25, 30]
group2 = [18, 22, 25, 28, 35]
group3 = [10, 14, 19, 23, 27]
data = [group1, group2, group3]
sns.violinplot(data=data, palette=['aquamarine', 'aqua', 'lightgreen'])
plt.title("Three Violin Plots")
plt.xlabel("Groups")
plt.ylabel("Values")
plt.show()

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris=load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
print("First 5 rows of dataset:")
print(df.head())
skewness_values=df.skew(numeric_only=True)
print("\nSkewness Values:")
print(skewness_values)
kurtosis_values=df.kurt(numeric_only=True)
print("\nKurtosis Values:")
print(kurtosis_values)
# Out:
# First 5 rows of dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Skewness Values:
# sepal length (cm)    0.314911
# sepal width (cm)     0.318966
# petal length (cm)   -0.274884
# petal width (cm)    -0.102967
# dtype: float64
#
# Kurtosis Values:
# sepal length (cm)   -0.552064
# sepal width (cm)     0.228249
# petal length (cm)   -1.402103
# petal width (cm)    -1.340604
# dtype: float64
